# %% [markdown]
# <a href="https://colab.research.google.com/github/Nurlu23/Nurlu23/blob/main/book/labs/lab_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab 1
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/giswqs/geog-312/blob/main/book/labs/lab_01.ipynb)

# %% [markdown]
# ## Exercise 1: Variable Assignment and Basic Operations
#
# Create variables to store the following geospatial data:
#
# - The latitude and longitude of New York City: 40.7128, -74.0060.
# - The population of New York City: 8,336,817.
# - The area of New York City in square kilometers: 783.8.
#
# Perform the following tasks:
#
# 1. Calculate and print the population density of New York City (population per square kilometer).
# 2. Print the coordinates in the format "Latitude: [latitude], Longitude: [longitude]".

# %%
# Variable assignment
latitude = 40.7128
longitude = -74.0060
population = 8_336_817
area_km2 = 783.8

# Calculate population density
population_density = population / area_km2

# Print results
print(f"Population Density: {population_density:.2f} people per square kilometer")
print(f"Latitude: {latitude}, Longitude: {longitude}")
# Out:
# Population Density: 10636.41 people per square kilometer
# Latitude: 40.7128, Longitude: -74.006

# %% [markdown]
# ## Exercise 2: Working with Strings
#
# Create a string variable to store the name of a city, such as "San Francisco". Perform the following operations:
#
# 1. Convert the string to lowercase and print the result.
# 2. Convert the string to uppercase and print the result.
# 3. Replace "San" with "Los" in the city name and print the new string.

# %%
# String variable
city = "San Francisco"

# Convert to lowercase
print(city.lower())

# Convert to uppercase
print(city.upper())

# Replace "San" with "Los"
new_city = city.replace("San", "Los")
print(new_city)
# Out:
# san francisco
# SAN FRANCISCO
# Los Francisco

# %% [markdown]
# ## Exercise 3: Using Lists
#
# Create a list of tuples, where each tuple contains the name of a city and its corresponding latitude and longitude:
#
# - New York City: (40.7128, -74.0060)
# - Los Angeles: (34.0522, -118.2437)
# - Chicago: (41.8781, -87.6298)
#
# Perform the following tasks:
#
# 1. Add a new city (e.g., Miami: (25.7617, -80.1918)) to the list.
# 2. Print the entire list of cities.
# 3. Slice the list to print only the first two cities.

# %%
# Create a list of tuples (city, (latitude, longitude))
cities = [
    ("New York City", (40.7128, -74.0060)),
    ("Los Angeles", (34.0522, -118.2437)),
    ("Chicago", (41.8781, -87.6298))
]

# Add a new city
cities.append(("Miami", (25.7617, -80.1918)))

# Print the entire list
print("All cities:")
print(cities)

# Slice the list to print only the first two cities
print("\nFirst two cities:")
print(cities[:2])
# Out:
# All cities:
# [('New York City', (40.7128, -74.006)), ('Los Angeles', (34.0522, -118.2437)), ('Chicago', (41.8781, -87.6298)), ('Miami', (25.7617, -80.1918))]
#
# First two cities:
# [('New York City', (40.7128, -74.006)), ('Los Angeles', (34.0522, -118.2437))]

# %% [markdown]
# ## Exercise 4: Using Tuples
#
# Create a tuple to store the coordinates (latitude, longitude) of the Eiffel Tower: (48.8584, 2.2945). Perform the following tasks:
#
# 1. Access and print the latitude and longitude values from the tuple.
# 2. Try to change the latitude value to 48.8585. What happens? Explain why.

# %%
# Create a tuple for the Eiffel Tower coordinates
eiffel_tower = (48.8584, 2.2945)

# Access latitude and longitude
latitude = eiffel_tower[0]
longitude = eiffel_tower[1]

# Print the values
print(f"Latitude: {latitude}")
print(f"Longitude: {longitude}")

# Try to change the latitude
eiffel_tower[0] = 48.8585
# Out:
# Latitude: 48.8584
# Longitude: 2.2945
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3823910120.py in <cell line: 0>()
#      11
#      12 # Try to change the latitude
# ---> 13 eiffel_tower[0] = 48.8585
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ## Exercise 5: Working with Sets
#
# Create a set of countries you have visited, such as {"USA", "France", "Germany"}. Perform the following tasks:
#
# 1. Add a new country to the set.
# 2. Try to add the same country again. What happens?
# 3. Print the updated set.

# %%
# Create a set of visited countries
visited_countries = {"USA", "France", "Germany"}

# Add a new country
visited_countries.add("Italy")

# Try to add the same country again
visited_countries.add("Italy")

# Print the updated set
print(visited_countries)
# Out:
# {'Italy', 'France', 'USA', 'Germany'}

# %% [markdown]
# ## Exercise 6: Working with Dictionaries
#
# Create a dictionary to store information about a specific geospatial feature, such as a river:
#
# - Name: "Amazon River"
# - Length: 6400 km
# - Countries: ["Brazil", "Peru", "Colombia"]
#
# Perform the following tasks:
#
# 1. Add a new key-value pair to the dictionary to store the river's average discharge (e.g., 209,000 m³/s).
# 2. Update the length of the river to 6992 km.
# 3. Print the dictionary.

# %%
# Create a dictionary for the river
river = {
    "Name": "Amazon River",
    "Length_km": 6400,
    "Countries": ["Brazil", "Peru", "Colombia"]
}

# Add a new key-value pair for average discharge
river["Average_Discharge_m3_s"] = 209_000

# Update the length of the river
river["Length_km"] = 6992

# Print the dictionary
print(river)
# Out:
# {'Name': 'Amazon River', 'Length_km': 6992, 'Countries': ['Brazil', 'Peru', 'Colombia'], 'Average_Discharge_m3_s': 209000}

# %% [markdown]
# ## Exercise 7: Nested Data Structures
#
# Create a dictionary to represent a city that contains the city's name, population, and coordinates (latitude, longitude):
#
# - Name: "Tokyo"
# - Population: 13,515,271
# - Coordinates: (35.6895, 139.6917)
#
# Perform the following tasks:
#
# 1. Access and print the population of the city.
# 2. Access and print the city's latitude.
# 3. Update the population to 14,000,000 and print the updated dictionary.

# %%
# Create a dictionary with nested data
city = {
    "Name": "Tokyo",
    "Population": 13_515_271,
    "Coordinates": (35.6895, 139.6917)
}

# Access and print the population
print("Population:", city["Population"])

# Access and print the latitude (first value in the tuple)
latitude = city["Coordinates"][0]
print("Latitude:", latitude)

# Update the population
city["Population"] = 14_000_000

# Print the updated dictionary
print("\nUpdated city dictionary:")
print(city)
# Out:
# Population: 13515271
# Latitude: 35.6895
#
# Updated city dictionary:
# {'Name': 'Tokyo', 'Population': 14000000, 'Coordinates': (35.6895, 139.6917)}

# %% [markdown]
# ## Exercise 8: List Operations
#
# Given the list of cities from Exercise 3, perform the following operations:
#
# 1. Sort the list of cities alphabetically by name.
# 2. Create a new list that contains only the city names.
# 3. Remove the last city from the original list and print the updated list.

# %%
# Original list of cities
cities = [
    ("New York City", (40.7128, -74.0060)),
    ("Los Angeles", (34.0522, -118.2437)),
    ("Chicago", (41.8781, -87.6298)),
    ("Miami", (25.7617, -80.1918))
]

# 1. Sort the list of cities alphabetically by city name
cities.sort(key=lambda city: city[0])

print("Sorted cities:")
print(cities)

# 2. Create a new list containing only the city names
city_names = [city[0] for city in cities]

print("\nCity names only:")
print(city_names)

# 3. Remove the last city from the original list
cities.pop()

print("\nUpdated cities list after removing the last city:")
print(cities)
# Out:
# Sorted cities:
# [('Chicago', (41.8781, -87.6298)), ('Los Angeles', (34.0522, -118.2437)), ('Miami', (25.7617, -80.1918)), ('New York City', (40.7128, -74.006))]
#
# City names only:
# ['Chicago', 'Los Angeles', 'Miami', 'New York City']
#
# Updated cities list after removing the last city:
# [('Chicago', (41.8781, -87.6298)), ('Los Angeles', (34.0522, -118.2437)), ('Miami', (25.7617, -80.1918))]

# %% [markdown]
# ## Exercise 9: Dictionary Operations
#
# Using the dictionary from Exercise 6, perform the following tasks:
#
# 1. Check if the key "Length" exists in the dictionary.
# 2. Print all the keys in the dictionary.
# 3. Print all the values in the dictionary.

# %%
# Dictionary from Exercise 6
river = {
    "Name": "Amazon River",
    "Length_km": 6992,
    "Countries": ["Brazil", "Peru", "Colombia"],
    "Average_Discharge_m3_s": 209_000
}

# 1. Check if the key "Length" exists in the dictionary
print("Does 'Length' exist?", "Length" in river)

# 2. Print all keys
print("\nDictionary keys:")
print(river.keys())

# 3. Print all values
print("\nDictionary values:")
print(river.values())
# Out:
# Does 'Length' exist? False
#
# Dictionary keys:
# dict_keys(['Name', 'Length_km', 'Countries', 'Average_Discharge_m3_s'])
#
# Dictionary values:
# dict_values(['Amazon River', 6992, ['Brazil', 'Peru', 'Colombia'], 209000])

# %% [markdown]
# ## Exercise 10: Practical Application
#
# Imagine you have a list of tuples, each representing a location with its name, latitude, and longitude:

# %%
locations = [
    ("Mount Everest", 27.9881, 86.9250),
    ("K2", 35.8808, 76.5155),
    ("Kangchenjunga", 27.7025, 88.1475),
]

# %% [markdown]
# Perform the following tasks:
#
# 1. Create a new list that contains only the names of the locations.
# 2. Create a dictionary where the keys are location names and the values are tuples of their coordinates.
# 3. Print the latitude of "K2" using the dictionary.

# %%
# Given list of locations
locations = [
    ("Mount Everest", 27.9881, 86.9250),
    ("K2", 35.8808, 76.5155),
    ("Kangchenjunga", 27.7025, 88.1475),
]

# 1. Create a list containing only the location names
location_names = [location[0] for location in locations]
print("Location names:")
print(location_names)

# 2. Create a dictionary with location names as keys and (lat, lon) as values
location_dict = {
    name: (lat, lon) for name, lat, lon in locations
}

print("\nLocation dictionary:")
print(location_dict)

# 3. Print the latitude of "K2"
k2_latitude = location_dict["K2"][0]
print("\nLatitude of K2:")
print(k2_latitude)
# Out:
# Location names:
# ['Mount Everest', 'K2', 'Kangchenjunga']
#
# Location dictionary:
# {'Mount Everest': (27.9881, 86.925), 'K2': (35.8808, 76.5155), 'Kangchenjunga': (27.7025, 88.1475)}
#
# Latitude of K2:
# 35.8808
